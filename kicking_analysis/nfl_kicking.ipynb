# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load data
df = pd.read_csv('kicking_data.csv')

print(df.head())
# Out:
#    Year  Teams  0-19 FGA  0-19 FGM  20-29 FGA  20-29 FGM  30-39 FGA  \
# 0  1960     13        14         8         13          8         20
# 1  1961     14        24        19         23         15         27
# 2  1962     14        22        20         20         13         27
# 3  1963     14        21        14         21         10         26
# 4  1964     14        30        20         28         21         35
#
#    30-39 FGM  40-49 FGA  40-49 FGM  ...  Total FGM  Total FG%  XPA  XPM  \
# 0         10         17          8  ...        163     56.00%  405  392
# 1         10         23          5  ...        179     48.10%  525  510
# 2         17         24          8  ...        180     49.50%  543  523
# 3         16         33         13  ...        188     49.60%  534  510
# 4         16         44         16  ...        214     53.10%  524  501
#
#       XP%  KO  KOYds  TB  TB%  KOAvg
# 0  96.80% NaN    NaN NaN  NaN    NaN
# 1  97.10% NaN    NaN NaN  NaN    NaN
# 2  96.30% NaN    NaN NaN  NaN    NaN
# 3  95.50% NaN    NaN NaN  NaN    NaN
# 4  95.60% NaN    NaN NaN  NaN    NaN
#
# [5 rows x 23 columns]

# %%
print(df['Total FG%'].head())
# Out:
# 0    56.00%
# 1    48.10%
# 2    49.50%
# 3    49.60%
# 4    53.10%
# Name: Total FG%, dtype: object

# %%
# create graph: Field Goal % by Year

year = df['Year']
stat = df['Total FGM']
FGM = df['Total FGM']
FGA = df['Total FGA']

fig, ax = plt.subplots(figsize=(13,5))
ax.plot(year, FGA, color='blue')
ax.plot(year, FGM, color='orange')

#ax.yaxis.set_ticks(np.arange(0, 100, 20))
ax.set_xlabel('Year')
ax.set_ylabel('Number Kicked')
ax.set_title('NFL FG Attempted vs Made from 1960-2024')
ax.set_facecolor('darkgreen')
fig.set_facecolor('grey')
ax.legend(['FGA', 'FGM'], loc='lower right', fontsize='large')
ax.grid()
plt.show()

# %%
ave = df['Total FGM'] / df['Total FGA'] * 100

print(ave.head())

fig, ax = plt.subplots(figsize=(13,5))
ax.plot(year, ave, color='purple')
ax.set_title('NFL FG% 1960 - 2024')
ax.set_xlabel('Year')
ax.set_ylabel('Field Goal %')
ax.set_facecolor('darkgreen')
fig.set_facecolor('gray')

plt.show()
# Out:
# 0    56.013746
# 1    48.118280
# 2    49.450549
# 3    49.604222
# 4    53.101737
# dtype: float64

# %%
total_ave = df['Total FGM'] / df['Total FGA'] * 100
ave019 = df['0-19 FGM'] / df['0-19 FGA'] * 100
ave2029 = df['20-29 FGM'] / df['20-29 FGA'] * 100
ave3039 = df['30-39 FGM'] / df['30-39 FGA'] * 100
ave4049 = df['40-49 FGM'] / df['40-49 FGA'] * 100
ave50 = df['50+ FGM'] / df['50+ FGA'] * 100

print(ave.head())

fig, ax = plt.subplots(figsize=(13,5))
ax.plot(year, total_ave, color='purple')
ax.plot(year, ave019)
ax.plot(year, ave2029)
ax.plot(year, ave3039)
ax.plot(year, ave4049)
ax.plot(year, ave50)
ax.set_title('NFL FG% by Distance 1960 - 2024')
ax.set_xlabel('Year')
ax.set_ylabel('Field Goal %')
ax.legend(['Total Ave', '0-19', '20-29', '30-39', '40-49', '50+'])
ax.set_facecolor('darkgreen')
fig.set_facecolor('gray')

plt.show()
# Out:
# 0    56.013746
# 1    48.118280
# 2    49.450549
# 3    49.604222
# 4    53.101737
# dtype: float64
